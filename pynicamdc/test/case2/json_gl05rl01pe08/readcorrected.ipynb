# %%
import json

# File path (update as needed)
json_file_path = "bboundary_GL05RL01.pe00000002.json"  # Change to your JSON file name

# Load JSON data
with open(json_file_path, "r") as json_file:
    data_arrays = json.load(json_file)

# Print available dataset names
print("Datasets in JSON file:", list(data_arrays.keys()))

# Example: Access a specific dataset (e.g., "grd_xt_jx")
dataset_name = "grd_xt_jy"  # Change to any dataset name you need
if dataset_name in data_arrays:
    dataset_values = data_arrays[dataset_name]  # Retrieve the dataset
#    print(f"First 5 rows of {dataset_name}:")
#    for row in dataset_values[:5]:  # Display first 5 rows
    for row in dataset_values[0]:
        print(row)
#    print (dataset_values)
else:
    print(f"Dataset {dataset_name} not found.")
# Out:
# Datasets in JSON file: ['grd_x_x', 'grd_x_y', 'grd_x_z', 'grd_xt_ix', 'grd_xt_jx', 'grd_xt_iy', 'grd_xt_jy', 'grd_xt_iz', 'grd_xt_jz']
# 0.32781080924297845
# 0.30835687163397796
# 0.28849900583857147
# 0.26839136387931584
# 0.2481620055953732
# 0.22790944031727223
# 0.2077079816538676
# 0.18761546109453456
# 0.1676798172616331
# 0.1479435657207363
# 0.12844610100181456
# 0.10922380567144555
# 0.09030759211370684
# 0.07171708315227819
# 0.05345059865697277
# 0.03547161307570124
# 0.017697105360348547
# -9.9999e+30
# 0.3099122210012453
# 0.2906597662735966
# 0.27095238136363003
# 0.2509514723548092
# 0.2307941723695704
# 0.21058780299274243
# 0.19041376634576307
# 0.1703345926532797
# 0.15040048206534928
# 0.1306540734051204
# 0.11113325553561534
# 0.09187204711657783
# 0.07289939801774231
# 0.054235475090323455
# 0.0358848022868267
# 0.017826014513761205
# 0.0
# -9.9999e+30
# 0.29165093288404365
# 0.27259306012364176
# 0.2530273927629244
# 0.2331254578410498
# 0.21303469654845503
# ...
